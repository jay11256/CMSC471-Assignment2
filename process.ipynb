# %%
# Importing libraries
import pandas as pd

# %%
# Data Loading
df = pd.read_csv("data/allegations.csv")
print(df.head())
print(df.shape)
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 df = pd.read_csv("data/allegations.csv")
#       3 df.head()
# ----> 4 df.shape()
#       5 df.columns()
#
# TypeError: 'tuple' object is not callable
